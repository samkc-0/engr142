# %% [markdown]
# # ENGR142 Assignment 1

# %% [markdown]
# **Term 2 2022**<br>
# **Due 5pm, 22<sup>nd</sup> July**<br>
# Sam Carter (300159820)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy.physics.units import meter, second, kilogram

m, s, kg = meter, second, kilogram
N = newton = kg * m * s**-2

# %% [markdown]
# ## Problem 1: Kinematics

# %% [markdown]
# ![pilots.jpg](attachment:pilots.jpg)

# %% [markdown]
# a. An airplane starts at rest and accelerates down a runway at 3.50 ms<sup>-2</sup> for 20 s until it finally lifts off the ground. Determine the distance travelled before takeoff.

# %% [markdown]
# ![apple.jpg.jpg](attachment:apple.jpg.jpg)

# %% [markdown]
# b. An apple falls from a tree and travels 3 m to the ground. The acceleration due to gravity has magnitude 9.8ms<sup>-2</sup>. Use two different methods *based only on kinematic equations* to find the speed of the apple when it hits the ground.

# %% [markdown]
# **[5 marks]**

# %% [markdown]
# <hr>

# %% [markdown]
# ## Problem 2: Vertical Stone throw

# %% [markdown]
# ![avengers_boulder.jpg](attachment:avengers_boulder.jpg)

# %% [markdown]
# a. A stone is thrown upwards at a speed of 25 ms<sup>-1</sup> from the top of a building of height 40 m. The stone narrowly misses the building on the way down and continues on to hit the ground below. Determine:

# %% [markdown]
# i. The total time taken before the stone hits the ground.

# %% [markdown]
# ii. The time taken for the stone to reach the top of its flight.

# %% [markdown]
# **[5 marks]**

# %% [markdown]
# <hr>

# %% [markdown]
# ## Problem 3: Undersea drama

# %% [markdown]
# ![shark_2.jpg](attachment:shark_2.jpg)

# %% [markdown]
# A shark travelling through the water at 5 ms<sup>-1</sup> sees a tasty-looking fish swimming past at -3 ms<sup>-1</sup> (i.e. the fish is swimming in the opposite direction). At the moment they pass each other the shark begins using its swimming prowess to accelerate at a rate of -6 ms<sup>-2</sup>, so that it slows down, turns around, and starts moving towards the fish. The fish is 10 m from a reef which will provide safety (i.e., the reef is at x = -10 m). Will the fish reach the reef before the shark catches it? Show your working. **[5 marks]**

# %% [markdown]
# <hr>

# %% [markdown]
# ## Problem 4: Olympic Sprinter

# %% [markdown]
# A sprinter running a 100 metre race accelerates for the first 4 seconds before travelling the rest of the race at constant speed. She starts from rest and completes the race in a time of 11 seconds. **[5 marks]**

# %% [markdown]
# a. What was her acceleration over the first 4 seconds?

# %% [markdown]
# b. Draw graphs of **displacement vs time** and **velocity vs time** for the sprinter
